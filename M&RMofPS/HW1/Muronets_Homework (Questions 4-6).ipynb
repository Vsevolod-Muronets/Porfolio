# %%
#Homework for the course of Methodology and Research Methods of Political Science
#Date: 05.12.2023
#Questions 4-6
#Author: Muronets Vsevolod Sergeevich (1st year PEP master's student)

#Problem 4

def tax_calc():
  y = int(input("Please enter your income: "));
  if y > 5000000:
    s = y/100*15;
    print("You are to pay: ", s)
  else:
    f = y/100*13;
    print("You are to pay: ", f)

tax_calc()

#Problem 5

def med_calc():
  y = input("Please enter a list of numbers using spaces: ");
  list = y.split();
  for i in range(len(list)):
    list[i] = int(list[i]);
  list.sort();
  if len(list) % 2 == 0:
    med1 = list[len(list) // 2];
    med2 = list[len(list) // 2-1];
    print("Median is ", (med1+med2)/2)
  else:
    median = list[len(list) // 2]
    print("Median is: ", median)

med_calc()

# Problem 6 (variant 1/2, with "bool()" function):

def set_equal():
  x = input("Please enter a list of numbers using spaces: ");
  y = input("Please enter another list of numbers using spaces: ");
  list1 = x.split();
  list2 = y.split();
  for i in range (len(list1)):
    list1[i] = int(list1[i]);
  for i in range (len(list2)):
    list2[i] = int(list2[i]);
  list1.sort();
  list2.sort();
  z = bool(list1 == list2);
  f = f'{z}';
  g = f.upper();
  print(g)

set_equal()

# Problem 6 (variant 2/2, without "bool()" function):

def set_equal():
  x = input("Please enter a list of numbers using spaces: ");
  y = input("Please enter another list of numbers using spaces: ");
  list1 = x.split();
  list2 = y.split();
  for i in range (len(list1)):
    list1[i] = int(list1[i]);
  for i in range (len(list2)):
    list2[i] = int(list2[i]);
  list1.sort();
  list2.sort();
  if list1 == list2:
    print("TRUE");
  else:
    print("FALSE")

set_equal()
