# %% [markdown]
# # Dependencies & Movies

# %%
from movielens_analysis import Movies, Ratings, Tags, Links
mov = Movies("movies.csv")
rat = Ratings("ratings.csv")
tag = Tags('tags.csv')
lnk = Links('links.csv')

# %timeit -n 1 -r 1 mov.dist_by_release()
mov.dist_by_release()
# Out:
# 536 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('1995', 224),
#              ('1994', 184),
#              ('1996', 181),
#              ('1993', 101),
#              ('1992', 23),
#              ('1990', 15),
#              ('1991', 15),
#              ('1989', 14),
#              ('1986', 9),
#              ('1982', 8),
#              ('1940', 8),
#              ('1957', 8),
#              ('1987', 8),
#              ('1980', 8),
#              ('1981', 7),
#              ('1988', 7),
#              ('1979', 7),
#              ('1955', 6),
#              ('1959', 6),
#              ('1968', 6),
#              ('1997', 6),
#              ('1939', 6),
#              ('1985', 6),
#              ('1967', 5),
#              ('1965', 5),
#              ('1951', 5),
#              ('1958', 5),
#              ('1944', 5),
#              ('1941', 5),
#              ('1975', 5),
#              ('1971', 5),
#              ('1984', 5),
# ...

# %%
# %timeit -n 1 -r 1 list(mov.dist_by_release().items())[:10]
list(mov.dist_by_release().items())[:10]
# Out:
# 422 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# [('1995', 224),
#  ('1994', 184),
#  ('1996', 181),
#  ('1993', 101),
#  ('1992', 23),
#  ('1990', 15),
#  ('1991', 15),
#  ('1989', 14),
#  ('1986', 9),
#  ('1982', 8)]

# %%
# %timeit -n 1 -r 1 mov.dist_by_genres()
mov.dist_by_genres()
# Out:
# 273 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Drama', 507),
#              ('Comedy', 365),
#              ('Romance', 208),
#              ('Thriller', 179),
#              ('Action', 158),
#              ('Adventure', 126),
#              ('Crime', 122),
#              ('Children', 100),
#              ('Fantasy', 69),
#              ('Sci-Fi', 69),
#              ('Mystery', 58),
#              ('Musical', 53),
#              ('Horror', 51),
#              ('War', 48),
#              ('Animation', 37),
#              ('Documentary', 25),
#              ('Western', 23),
#              ('Film-Noir', 18),
#              ('IMAX', 3)])

# %%
# %timeit -n 1 -r 1 list(mov.dist_by_genres().items())[:10]
list(mov.dist_by_genres().items())[:10]
# Out:
# 248 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# [('Drama', 507),
#  ('Comedy', 365),
#  ('Romance', 208),
#  ('Thriller', 179),
#  ('Action', 158),
#  ('Adventure', 126),
#  ('Crime', 122),
#  ('Children', 100),
#  ('Fantasy', 69),
#  ('Sci-Fi', 69)]

# %%
# %timeit -n 1 -r 1 mov.most_genres(10)
mov.most_genres(10)
# Out:
# 384 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Strange Days (1995)', 6),
#              ('Lion King, The (1994)', 6),
#              ('Getaway, The (1994)', 6),
#              ('Super Mario Bros. (1993)', 6),
#              ('Beauty and the Beast (1991)', 6),
#              ('All Dogs Go to Heaven 2 (1996)', 6),
#              ('Space Jam (1996)', 6),
#              ('Aladdin and the King of Thieves (1996)', 6),
#              ('Toy Story (1995)', 5),
#              ('Money Train (1995)', 5)])

# %% [markdown]
# # Ratings

# %%
r_movies = Ratings.Movies(rat.ratings)

# %timeit -n 1 -r 1 r_movies.dist_by_year()
r_movies.dist_by_year()
# Out:
# 381 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([(1996, 358),
#              (1999, 82),
#              (2000, 296),
#              (2001, 70),
#              (2005, 121),
#              (2006, 4),
#              (2007, 1),
#              (2011, 39),
#              (2015, 29)])

# %%
# %timeit -n 1 -r 1 (list(r_movies.dist_by_year().items())[:5], list(r_movies.dist_by_year().items())[-5:])
(list(r_movies.dist_by_year().items())[:5], list(r_movies.dist_by_year().items())[-5:])
# Out:
# 760 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# ([(1996, 358), (1999, 82), (2000, 296), (2001, 70), (2005, 121)],
#  [(2005, 121), (2006, 4), (2007, 1), (2011, 39), (2015, 29)])

# %%
# %timeit -n 1 -r 1 r_movies.dist_by_rating()
r_movies.dist_by_rating()
# Out:
# 182 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([(0.5, 24),
#              (1.0, 39),
#              (1.5, 11),
#              (2.0, 57),
#              (2.5, 7),
#              (3.0, 253),
#              (3.5, 17),
#              (4.0, 292),
#              (4.5, 33),
#              (5.0, 267)])

# %%
# %timeit -n 1 -r 1 list(r_movies.dist_by_rating().items())
list(r_movies.dist_by_rating().items())
# Out:
# 190 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# [(0.5, 24),
#  (1.0, 39),
#  (1.5, 11),
#  (2.0, 57),
#  (2.5, 7),
#  (3.0, 253),
#  (3.5, 17),
#  (4.0, 292),
#  (4.5, 33),
#  (5.0, 267)]

# %%
# %timeit -n 1 -r 1 r_movies.top_by_num_of_ratings(10)
r_movies.top_by_num_of_ratings(10)
# Out:
# 2.6 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Usual Suspects, The (1995)', 4),
#              ('Pulp Fiction (1994)', 4),
#              ('Fugitive, The (1993)', 4),
#              ("Schindler's List (1993)", 4),
#              ('Batman (1989)', 4),
#              ('Silence of the Lambs, The (1991)', 4),
#              ('Fargo (1996)', 4),
#              ('Aladdin (1992)', 4),
#              ('Beauty and the Beast (1991)', 4),
#              ('Toy Story (1995)', 3)])

# %%
# %timeit -n 1 -r 1 r_movies.top_by_ratings(10, metric="average")
r_movies.top_by_ratings(10, metric="average")
# Out:
# 5.15 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Bottle Rocket (1996)', 5.0),
#              ('Canadian Bacon (1995)', 5.0),
#              ('Star Wars: Episode IV - A New Hope (1977)', 5.0),
#              ('James and the Giant Peach (1996)', 5.0),
#              ('Wizard of Oz, The (1939)', 5.0),
#              ('Citizen Kane (1941)', 5.0),
#              ('Adventures of Robin Hood, The (1938)', 5.0),
#              ('Mr. Smith Goes to Washington (1939)', 5.0),
#              ('Winnie the Pooh and the Blustery Day (1968)', 5.0),
#              ('Three Caballeros, The (1945)', 5.0)])

# %%
# %timeit -n 1 -r 1 r_movies.top_by_ratings(10, metric="median")
r_movies.top_by_ratings(10, metric="median")
# Out:
# 2.93 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Bottle Rocket (1996)', 5.0),
#              ('Canadian Bacon (1995)', 5.0),
#              ('Star Wars: Episode IV - A New Hope (1977)', 5.0),
#              ('Tommy Boy (1995)', 5.0),
#              ('Forrest Gump (1994)', 5.0),
#              ('Fugitive, The (1993)', 5.0),
#              ('Jurassic Park (1993)', 5.0),
#              ('Tombstone (1993)', 5.0),
#              ('Dances with Wolves (1990)', 5.0),
#              ('Pinocchio (1940)', 5.0)])

# %%
# %timeit -n 1 -r 1 r_movies.top_controversial(10)
r_movies.top_controversial(10)
# Out:
# 3.63 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Movie_2018', 5.06),
#              ('Movie_2090', 5.06),
#              ('My Fair Lady (1964)', 5.06),
#              ('Movie_2571', 4.0),
#              ("Schindler's List (1993)", 3.42),
#              ('Movie_1704', 3.06),
#              ('Courage Under Fire (1996)', 3.06),
#              ('Usual Suspects, The (1995)', 2.42),
#              ('Dazed and Confused (1993)', 2.25),
#              ('Movie_2959', 2.25)])

# %%
r_users = Ratings.Users(rat.ratings)

# %timeit -n 1 -r 1 r_users.dist_by_num_of_ratings()
r_users.dist_by_num_of_ratings()
# Out:
# 86.2 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([(6, 314),
#              (1, 232),
#              (4, 216),
#              (7, 126),
#              (5, 44),
#              (3, 39),
#              (2, 29)])

# %%
# %timeit -n 1 -r 1 list(r_users.dist_by_num_of_ratings().items())[:10]
list(r_users.dist_by_num_of_ratings().items())[:10]
# Out:
# 84.2 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# [(6, 314), (1, 232), (4, 216), (7, 126), (5, 44), (3, 39), (2, 29)]

# %%
# %timeit -n 1 -r 1 r_users.dist_by_average()
r_users.dist_by_average()
# Out:
# 156 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([(1, 4.37),
#              (2, 3.95),
#              (5, 3.64),
#              (4, 3.56),
#              (6, 3.49),
#              (7, 3.35),
#              (3, 2.44)])

# %%
# %timeit -n 1 -r 1 (list(r_users.dist_by_average().items())[:10], list(r_users.dist_by_average().items())[-10:])
(list(r_users.dist_by_average().items())[:10], list(r_users.dist_by_average().items())[-10:])
# Out:
# 166 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# ([(1, 4.37), (2, 3.95), (5, 3.64), (4, 3.56), (6, 3.49), (7, 3.35), (3, 2.44)],
#  [(1, 4.37), (2, 3.95), (5, 3.64), (4, 3.56), (6, 3.49), (7, 3.35), (3, 2.44)])

# %%
# %timeit -n 1 -r 1 r_users.top_controversial_users(10)
r_users.top_controversial_users(10)
# Out:
# 207 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([(3, 4.26),
#              (4, 1.72),
#              (7, 1.65),
#              (5, 0.96),
#              (6, 0.72),
#              (1, 0.64),
#              (2, 0.63)])

# %% [markdown]
# # Tags

# %%
# %timeit -n 1 -r 1 tag.most_words(10)
tag.most_words(10)
# Out:
# 262 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Something for everyone in this one... saw it without and plan on seeing it with kids!',
#               16),
#              ('the catholic church is the most corrupt organization in history',
#               10),
#              ('Oscar (Best Music - Original Score)', 6),
#              ('Everything you want is here', 5),
#              ('based on a true story', 5),
#              ('heroine in tight suit', 4),
#              ('Guardians of the Galaxy', 4),
#              ('a clever chef rat', 4),
#              ('jay and silent bob', 4),
#              ('based on a book', 4)])

# %%
# %timeit -n 1 -r 1 tag.longest(10)
tag.longest(10)
# Out:
# 113 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# ['Something for everyone in this one... saw it without and plan on seeing it with kids!',
#  'the catholic church is the most corrupt organization in history',
#  'audience intelligence underestimated',
#  'Oscar (Best Music - Original Score)',
#  'assassin-in-training (scene)',
#  'Everything you want is here',
#  'political right versus left',
#  'Oscar (Best Cinematography)',
#  'representation of children',
#  'Guardians of the Galaxy']

# %%
# %timeit -n 1 -r 1 tag.most_words_and_longest(10)
tag.most_words_and_longest(10)
# Out:
# 289 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# ['Everything you want is here',
#  'Guardians of the Galaxy',
#  'Oscar (Best Music - Original Score)',
#  'Something for everyone in this one... saw it without and plan on seeing it with kids!',
#  'the catholic church is the most corrupt organization in history']

# %%
# %timeit -n 1 -r 1 tag.most_popular(10)
tag.most_popular(10)
# Out:
# 156 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('funny', 15),
#              ('sci-fi', 14),
#              ('twist ending', 12),
#              ('dark comedy', 12),
#              ('atmospheric', 10),
#              ('superhero', 10),
#              ('comedy', 10),
#              ('action', 10),
#              ('suspense', 10),
#              ('Leonardo DiCaprio', 9)])

# %%
# %timeit -n 1 -r 1 tag.tags_with("fun")
tag.tags_with("fun")
# Out:
# 115 μs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# ['fun family movie', 'funny', 'stupid but funny', 'very funny']

# %% [markdown]
# # Links

# %%
# %timeit -n 1 -r 1 lnk.get_imdb([1, 2, 3, 10], ["Director", "Budget", "Runtime"])
lnk.get_imdb([1, 2, 3, 10], ["Director", "Budget", "Runtime"])
# Out:
# 3.87 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# [[10, 'Martin Campbell', '60000000', '(130 min)'],
#  [3, 'Howard Deutch', '25000000', '(101 min)'],
#  [2, 'Joe Johnston', '65000000', '(104 min)'],
#  [1, 'John Lasseter', '30000000', '(81 min)']]

# %%
# %timeit -n 1 -r 1 lnk.top_directors(3)
lnk.top_directors(3)
# Out:
# 24min 4s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Alfred Hitchcock', 11),
#              ('Woody Allen', 8),
#              ('Stanley Kubrick', 6)])

# %%
# %timeit -n 1 -r 1 lnk.most_expensive(5)
lnk.most_expensive(5)
# Out:
# 24min 33s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Akira', 1100000000),
#              ('Kôkaku kidôtai', 330000000),
#              ('Lumea acvatică', 175000000),
#              ('Germinal', 164000000),
#              ('Á köldum klaka', 130000000)])

# %%
# %timeit -n 1 -r 1 lnk.most_profitable(5)
lnk.most_profitable(5)
# Out:
# 25min 8s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Jurassic Park', 1040096466),
#              ('Regele Leu', 934161632),
#              ('E.T. Extraterestrul', 786807407),
#              ('Războiul stelelor - Episodul IV: O nouă speranță', 764398507),
#              ('Ziua independentei', 742400891)])

# %%
# %timeit -n 1 -r 1 lnk.longest(5)
lnk.longest(5)
# Out:
# 24min 42s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Pe aripile vântului', 238),
#              ('A fost odată în America', 229),
#              ('Lawrence din Arabia', 227),
#              ('Ben-Hur', 212),
#              ('Nașul: Partea a II-a', 202)])

# %%
# %timeit -n 1 -r 1 lnk.top_cost_per_minute(5)
lnk.top_cost_per_minute(5)
# Out:
# 24min 50s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# OrderedDict([('Akira', 8870967.74),
#              ('Kôkaku kidôtai', 3975903.61),
#              ('Á köldum klaka', 1566265.06),
#              ('Lumea acvatică', 1296296.3),
#              ('Cocosatul de la Notre Dame', 1098901.1)])
